# %%
age = int(input("input your age : "))

if age >= 18:
    print("eligible for vote")
else :
    print("not eligible for vote")
# Out:
# input your age :  12
# not eligible for vote

# %%
num = int(input("input number : "))
if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# input number :  23
# Odd Number

# %%
#table
num = int(input("input number : "))
i=1
while i<=10 :
    print(num, " x ", i ," = ",num*i)
    i+=1
# Out:
# input number :  3
# 3  x  1  =  3
# 3  x  2  =  6
# 3  x  3  =  9
# 3  x  4  =  12
# 3  x  5  =  15
# 3  x  6  =  18
# 3  x  7  =  21
# 3  x  8  =  24
# 3  x  9  =  27
# 3  x  10  =  30

# %%
#largest amoung 3 values
num1 = int(input("input number 1 : "))
num2 = int(input("input number 2 : "))
num3 = int(input("input numbder 3 : "))

if num1 > num2 and num1 > num3 :
     print("Greatest number is :- ",num1)
elif num2 > num1 and num2 > num3 :
     print("Greatest number is :- ",num2)
else:
    print("Greatest number is :- ",num3)
# Out:
# input number 1 :  12
# input number 2 :  34
# input number 3 :  45
# Greatest number is :-  45
